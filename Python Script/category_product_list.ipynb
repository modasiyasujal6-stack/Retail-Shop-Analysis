# %%
categories_with_products = {
    "Beverages": [
        "Coca Cola", "Pepsi", "Sprite", "Fanta", "Thums Up", "7 Up", "Maaza", "Slice", "Appy Fizz", "Red Bull",
        "Monster", "Paper Boat", "Real Juice", "Tropicana", "Bisleri Soda", "Catch Soda", "Sting", "Mountain Dew",
        "Bailley Soda", "Bovonto", "Limca", "Bournvita", "Horlicks", "Boost", "Complan", "Amul Kool", "Nescafe",
        "Bru Coffee", "Green Tea", "Iced Tea", "Badam Drink", "Jeera Soda", "Sugarcane Juice", "Buttermilk", "Lassi",
        "Coconut Water", "Herbal Drink", "Mocktail Mix", "Electral"
    ],
    "Snacks": [
        "Lay's Chips", "Kurkure", "Balaji Wafers", "Bingo Mad Angles", "Too Yumm", "Uncle Chips", "Pringles", "Doritos",
        "Popcorn", "Nachos", "Haldiram Bhujia", "Aloo Bhujia", "Moong Dal", "Chana Dal", "Soya Sticks", "Diet Chips",
        "Banana Chips", "Sweet Potato Chips", "Khakhra", "Papdi", "Namkeen Mixture", "Cheese Balls", "Puffed Rice",
        "Masala Peanuts", "Mini Samosa", "Mini Kachori", "Sev", "Gathiya", "Chakli", "Chivda", "Farsan", "Bhakarwadi",
        "Dry Fruit Mix", "Roasted Makhana", "Baked Chips", "Oats Chips", "Ragi Chips", "Quinoa Snacks", "Protein Chips"
    ],
    "Dairy": [
        "Amul Milk", "Mother Dairy", "Paneer", "Cheese Slice", "Butter", "Curd", "Yogurt", "Ghee", "Flavored Milk",
        "Lassi", "Buttermilk", "Malai", "Cream", "Chaas", "Tofu", "Milkmaid", "Condensed Milk", "Milk Powder",
        "Cheese Cubes", "Whipped Cream", "Cheddar", "Mozzarella", "Processed Cheese", "Low Fat Milk", "Skimmed Milk",
        "Cow Milk", "Buffalo Milk", "Organic Milk", "Dahi", "Greek Yogurt", "Probiotic Drink", "Ice Cream",
        "Kulfi", "Milk Shake", "Choco Milk", "Butter Milk", "Soft Cheese", "Ricotta", "Blue Cheese", "Parmesan"
    ],
    "Bakery": [
        "White Bread", "Brown Bread", "Multigrain Bread", "Pav", "Buns", "Burger Buns", "Garlic Bread", "Pizza Base",
        "Cake", "Pastry", "Muffins", "Donuts", "Croissant", "Cookies", "Biscuits", "Toast", "Rusk", "Khari",
        "Cream Roll", "Swiss Roll", "Plum Cake", "Cupcake", "Breadsticks", "Bagel", "Naan", "Kulcha", "Focaccia",
        "Danish", "Biscotti", "Waffle", "Pan Cake", "Bread Loaf", "Tart", "Puff", "Doughnut", "Shortbread", "Crisp",
        "Lavash", "Crackers"
    ],
    "Personal Care": [
        "Lifebuoy Soap", "Dettol", "Lux", "Dove", "Pears", "Santoor", "Cinthol", "Himalaya Facewash", "Face Scrub",
        "Shampoo", "Conditioner", "Hair Oil", "Hair Gel", "Toothpaste", "Toothbrush", "Mouthwash", "Shaving Cream",
        "Razor", "Deodorant", "Perfume", "Face Cream", "Body Lotion", "Lip Balm", "Sunscreen", "Hand Wash",
        "Sanitizer", "Talcum Powder", "Wet Wipes", "Face Mask", "Face Serum", "Nail Cutter", "Comb", "Shower Gel",
        "Body Scrub", "Beard Oil", "After Shave", "Hair Serum", "Lipstick", "Kajal"
    ],
    "Household": [
        "Vim Bar", "Harpic", "Lizol", "Phenyl", "Toilet Cleaner", "Floor Cleaner", "Dishwash Gel", "Scrubber",
        "Toilet Brush", "Room Freshener", "Naphthalene Balls", "Mosquito Coil", "Good Knight", "All Out", "Mop",
        "Broom", "Dustbin", "Garbage Bag", "Match Box", "Lighter", "Candle", "Bulb", "Battery", "Extension Cord",
        "Cleaning Cloth", "Washing Powder", "Detergent", "Bucket", "Mug", "Soap Case", "Tissue Paper", "Hand Gloves",
        "Spray Bottle", "Door Mat", "Air Freshener", "Glass Cleaner", "Sponge", "Drain Cleaner", "Lint Roller", "Towel"
    ],
    "Fruits": [
        "Apple", "Banana", "Mango", "Orange", "Pineapple", "Watermelon", "Papaya", "Grapes", "Pomegranate", "Guava",
        "Lychee", "Cherry", "Peach", "Plum", "Kiwi", "Strawberry", "Blueberry", "Raspberry", "Blackberry", "Coconut",
        "Tender Coconut", "Muskmelon", "Dragon Fruit", "Avocado", "Star Fruit", "Custard Apple", "Fig", "Pear",
        "Sweet Lime", "Sapota", "Tamarind", "Dates", "Jamun", "Amla", "Jackfruit", "Longan", "Passion Fruit",
        "Mulberry", "Cranberry", "Apricot"
    ],
    "Vegetables": [
        "Potato", "Tomato", "Onion", "Carrot", "Beetroot", "Cabbage", "Cauliflower", "Spinach", "Coriander",
        "Fenugreek", "Ginger", "Garlic", "Green Chili", "Red Chili", "Brinjal", "Lady Finger", "Capsicum", "Cucumber",
        "Bitter Gourd", "Bottle Gourd", "Ridge Gourd", "Pumpkin", "Radish", "Turnip", "Spring Onion", "Lettuce",
        "Broccoli", "Mushroom", "Corn", "Green Peas", "French Beans", "Drumstick", "Raw Banana", "Yam", "Sweet Potato",
        "Avarekai", "Cluster Beans", "Curry Leaves", "Mint"
    ],
    "Frozen Foods": [
        "Frozen Paratha", "Frozen Peas", "Frozen Corn", "Frozen French Fries", "Frozen Samosa", "Frozen Kachori",
        "Frozen Paneer", "Frozen Spring Roll", "Frozen Veg Mix", "Frozen Chapati", "Frozen Roti", "Frozen Naan",
        "Frozen Dosa", "Frozen Idli", "Frozen Pizza Base", "Frozen Chicken", "Frozen Fish", "Frozen Prawns",
        "Frozen Tandoori", "Frozen Nuggets", "Frozen Kebabs", "Frozen Cutlets", "Frozen Tikki", "Frozen Momos",
        "Frozen Waffles", "Frozen Kulfi", "Frozen Ice Cream", "Frozen Cheese", "Frozen Berries", "Frozen Mango",
        "Frozen Strawberry", "Frozen Fruits", "Frozen Mix Veg", "Frozen Coconut", "Frozen Milk", "Frozen Yogurt",
        "Frozen Butter", "Frozen Garlic", "Frozen Herbs", "Frozen Ready Meal"
    ],
    "Grocery & Staples": [
        "Basmati Rice", "Brown Rice", "Sona Masoori Rice", "Wheat Flour", "Maida", "Rava", "Besan", "Sugar", "Salt",
        "Jaggery", "Tur Dal", "Moong Dal", "Chana Dal", "Urad Dal", "Masoor Dal", "Rajma", "Chole", "Kabuli Chana",
        "Black Urad", "Lobia", "Green Gram", "Poha", "Sabudana", "Vermicelli", "Sooji", "Ragi Flour", "Bajra Flour",
        "Multigrain Flour", "Rice Flour", "Corn Flour", "Mustard Seeds", "Cumin Seeds", "Fennel Seeds", "Fenugreek",
        "Cardamom", "Cloves", "Cinnamon", "Black Pepper", "Bay Leaf"
    ],
    "Spices & Masalas": [
        "Turmeric Powder", "Red Chili Powder", "Coriander Powder", "Cumin Powder", "Garam Masala", "Sambhar Masala",
        "Chole Masala", "Pav Bhaji Masala", "Kitchen King", "Biryani Masala", "Meat Masala", "Chicken Masala",
        "Fish Masala", "Chat Masala", "Amchur Powder", "Kasuri Methi", "Hing", "Mustard Seeds", "Ajwain", "Black Salt",
        "White Pepper", "Curry Leaves", "Dry Ginger", "Garlic Powder", "Onion Powder", "Tandoori Masala",
        "Tea Masala", "Paneer Masala", "Pickle Masala", "Peri Peri Masala", "Chinese Masala", "Pizza Seasoning",
        "Oregano", "Chili Flakes", "Cloves", "Cardamom", "Black Cardamom", "Bay Leaf", "Star Anise"
    ],
    "Breakfast Items": [
        "Corn Flakes", "Chocos", "Oats", "Muesli", "Poha", "Upma Mix", "Idli Mix", "Dosa Mix", "Pancake Mix",
        "Porridge", "Ready Roti", "Ready Dhokla Mix", "Semolina", "Wheat Dalia", "Ragi Dosa Mix", "Instant Oats",
        "Granola", "Pita Bread", "Bagels", "Bread Rolls", "Breakfast Sausage", "Hash Browns", "Omelette Mix",
        "Flavored Yogurt", "Cheese Spread", "Protein Bar", "Breakfast Cereal", "Coconut Chutney Mix", "Peanut Butter",
        "Jam", "Honey", "Almond Butter", "Chutney", "Instant Tea", "Masala Oats", "Ready Upma", "Tofu Cubes",
        "Eggs", "Boiled Eggs"
    ],
    "Dry Fruits & Nuts": [
        "Almonds", "Cashews", "Pistachios", "Walnuts", "Raisins", "Dates", "Dry Figs", "Apricots", "Prunes",
        "Dry Coconut", "Fox Nuts", "Flax Seeds", "Chia Seeds", "Sunflower Seeds", "Pumpkin Seeds", "Sesame Seeds",
        "Peanuts", "Hazelnuts", "Brazil Nuts", "Macadamia", "Pine Nuts", "Roasted Almonds", "Salted Cashews",
        "Caramelized Nuts", "Mixed Nuts", "Spicy Nuts", "Dry Fruit Mix", "Trail Mix", "Dry Fruit Laddu",
        "Energy Mix", "Dry Fruit Bites", "Date Rolls", "Dry Anjeer", "Dry Kiwi", "Dry Mango", "Dry Apple",
        "Dry Orange", "Chocolate Coated Almonds", "Honey Coated Nuts"
    ],
    "Oils & Ghee": [
        "Sunflower Oil", "Mustard Oil", "Groundnut Oil", "Coconut Oil", "Soybean Oil", "Rice Bran Oil",
        "Olive Oil", "Sesame Oil", "Corn Oil", "Palm Oil", "Blended Oil", "Ghee", "Cow Ghee", "Buffalo Ghee",
        "Organic Ghee", "Vanaspati", "Cold Pressed Oil", "Extra Virgin Oil", "Refined Oil", "Desi Ghee",
        "Cooking Spray", "Canola Oil", "Avocado Oil", "Almond Oil", "Flaxseed Oil", "Safflower Oil", "Butter Ghee",
        "Herbal Oil", "A2 Ghee", "Pure Mustard Oil", "Neem Oil", "Rice Oil", "Gingelly Oil", "Groundnut Cold Pressed",
        "Pure Coconut Oil", "Sesame Cold Pressed", "Vegetable Oil", "Palmolein Oil", "Toasted Sesame Oil"
    ],
    "Pickles & Chutneys": [
        "Mango Pickle", "Lemon Pickle", "Mixed Pickle", "Green Chili Pickle", "Garlic Pickle", "Amla Pickle",
        "Red Chili Pickle", "Sweet Mango Pickle", "Ker Sangri Pickle", "Punjabi Pickle", "South Indian Pickle",
        "Gujarati Pickle", "Pickle in Oil", "Pickle in Vinegar", "Tomato Pickle", "Onion Pickle", "Carrot Pickle",
        "Stuffed Pickle", "Home Style Pickle", "Spicy Pickle", "Coriander Chutney", "Mint Chutney", "Garlic Chutney",
        "Tamarind Chutney", "Coconut Chutney", "Peanut Chutney", "Sesame Chutney", "Dry Chutney Powder",
        "Chili Garlic Chutney", "Chundo", "Lime Chutney", "Khatti Meethi Chutney", "Mango Chutney", "Date Chutney",
        "Onion Chutney", "Ready Mix Chutney", "Thokku", "Tomato Chutney", "Curry Leaf Chutney"
    ],
    "Instant Foods": [
        "Instant Noodles", "Cup Noodles", "Ready Pasta", "Instant Upma", "Ready Poha", "Instant Idli", "Ready Dosa",
        "Ready Rice", "Ready Khichdi", "Biryani Mix", "Pulao Mix", "Instant Soup", "Ready Curry", "Instant Dal",
        "Macaroni", "Spaghetti", "Ramen", "Ready Pizza", "Frozen Biryani", "Ready Roti", "Dhokla Mix", "Khaman Mix",
        "Ready Mix Pav Bhaji", "Ready Mix Sambar", "Ready Mix Rasam", "Ready Mix Halwa", "Ready Mix Cake",
        "Muffin Mix", "Instant Pancake", "Instant Kheer", "Instant Pasta", "Pasta Sauce", "Pizza Sauce",
        "Noodle Masala", "Ready Fried Rice", "Frozen Lasagna", "Instant Oats", "Oats Noodles", "Tomato Soup"
    ],
    "Baby Care": [
        "Baby Diapers", "Wet Wipes", "Baby Powder", "Baby Lotion", "Baby Shampoo", "Baby Oil", "Baby Soap",
        "Baby Cream", "Baby Toothpaste", "Baby Toothbrush", "Baby Food", "Formula Milk", "Baby Cereal",
        "Teething Toy", "Baby Comb", "Nappy Cream", "Feeding Bottle", "Bottle Warmer", "Sippy Cup", "Baby Blanket",
        "Baby Towel", "Baby Wipes", "Changing Mat", "Pacifier", "Baby Detergent", "Baby Nail Cutter", "Baby Spoon",
        "Baby Plate", "Baby Bowl", "Baby Thermometer", "Baby Carrier", "Baby Stroller", "Diaper Bag", "Rattle",
        "Bath Tub", "Baby Bib", "Safety Pins", "Baby Bed", "Baby Pillow"
    ],
    "Pet Supplies": [
        "Dog Food", "Cat Food", "Pet Shampoo", "Pet Soap", "Pet Conditioner", "Dog Collar", "Pet Comb", "Cat Litter",
        "Dog Toy", "Cat Toy", "Pet Towel", "Dog Chew", "Dog Treats", "Cat Treats", "Fish Food", "Bird Food",
        "Pet Vitamins", "Pet Supplements", "Pet Bed", "Dog Chain", "Pet Bowl", "Pet Carrier", "Dog Clothes",
        "Cat Scratcher", "Pet Brush", "Tick Powder", "Flea Shampoo", "Pet Deodorant", "Dog Biscuit", "Cat Biscuit",
        "Aquarium Cleaner", "Bird Cage", "Dog Harness", "Cat Collar", "Pet Wipes", "Pet Toothbrush", "Pet Nail Cutter",
        "Pet Water Bottle", "Pet Tracker"
    ],
    "Stationery": [
        "Pen", "Pencil", "Notebook", "Eraser", "Sharpener", "Ruler", "Scale", "Compass", "Protractor", "Geometry Box",
        "File", "Folder", "Marker", "Highlighter", "Stapler", "Staples", "Glue", "Scissors", "Sketch Pens",
        "Color Pencils", "Crayons", "Drawing Book", "Chart Paper", "Sticky Notes", "Correction Pen", "Board Marker",
        "White Board", "Black Board", "Clipboard", "ID Card Holder", "Calculator", "Exam Pad", "Pen Drive", "Binder Clips",
        "Paper Pins", "Dustbin", "Duster", "Tape", "Label Stickers"
    ],
    "Pooja Items": [
        "Agarbatti", "Camphor", "Cotton Wick", "Diya", "Ghee Diya", "Pooja Oil", "Pooja Thali", "Kumkum", "Haldi",
        "Chandan", "Bell", "Incense Stick", "Pooja Cloth", "Pooja Samagri", "Match Box", "Kalash", "Coconut", "Dhoop",
        "Brass Diya", "Silver Diya", "Turmeric Stick", "Sindoor", "Sacred Thread", "Panchpatra", "Aarti Book",
        "Holy Water", "Tulsi Leaves", "Ganga Jal", "Pooja Garland", "Ghee Wicks", "Dhoop Cone", "Pooja Stand",
        "Shankh", "Pooja Box", "Temple Bell", "Decorative Kalash", "Betel Leaves", "Betel Nut", "Janoi"
    ],
    "Health & Wellness": [
        "Multivitamins", "Calcium Tablets", "Vitamin C", "Fish Oil", "Omega 3", "Iron Tablets", "Protein Powder",
        "Whey Protein", "Herbal Supplements", "Ayurvedic Capsules", "Green Tea Bags", "Detox Tea", "Chyawanprash",
        "Energy Drink", "ORS Powder", "Glucon D", "Electral Sachet", "Pain Relief Balm", "Pain Relief Spray",
        "Hot Water Bag", "BP Monitor", "Thermometer", "Face Mask", "Hand Sanitizer", "Disinfectant Wipes",
        "Steam Inhaler", "Nebulizer", "Antiseptic Cream", "Cough Syrup", "Throat Lozenges", "Diabetic Biscuits",
        "Sugar-Free Tablets", "Joint Pain Capsules", "Ashwagandha", "Giloy Tablets", "Spirulina", "Protein Bar",
        "Aloe Vera Juice", "Apple Cider Vinegar"
    ],
    "Meat & Seafood": [
        "Chicken Breast", "Chicken Thigh", "Whole Chicken", "Boneless Chicken", "Mutton Curry Cut", "Mutton Keema",
        "Fish Fillet", "Rohu Fish", "Catla Fish", "Prawns", "Tuna", "Salmon", "Pomfret", "Crab", "Lobster",
        "Eggs - Regular", "Brown Eggs", "Quail Eggs", "Duck Eggs", "Frozen Chicken Sausage", "Fish Fingers",
        "Chicken Nuggets", "Chicken Salami", "Mutton Seekh Kebab", "Chicken Tikka", "Marinated Fish", "Marinated Chicken",
        "Fish Curry Cut", "Seafood Mix", "Fish Roe", "Dry Fish", "Chicken Liver", "Chicken Wings", "Turkey Slices",
        "Smoked Fish", "Fish Pickle", "Shellfish", "Anchovy", "Tandoori Chicken"
    ],
    "Organic Products": [
        "Organic Rice", "Organic Wheat", "Organic Moong Dal", "Organic Chana", "Organic Jaggery", "Organic Brown Sugar",
        "Organic Turmeric", "Organic Red Chili", "Organic Cumin", "Organic Coriander", "Organic Cardamom",
        "Organic Coconut Oil", "Organic Sesame Oil", "Organic Mustard Oil", "Organic Tea", "Organic Coffee",
        "Organic Apple", "Organic Banana", "Organic Mango", "Organic Spinach", "Organic Carrot", "Organic Tomato",
        "Organic Potato", "Organic Milk", "Organic Paneer", "Organic Eggs", "Organic Honey", "Organic Ghee",
        "Organic Butter", "Organic Flour", "Organic Cornflakes", "Organic Muesli", "Organic Soup Mix",
        "Organic Dry Fruits", "Organic Pickle", "Organic Jam", "Organic Spices", "Organic Pasta", "Organic Noodles"
    ],
    "Cleaning & Laundry": [
        "Washing Powder", "Liquid Detergent", "Fabric Conditioner", "Bleach", "Toilet Cleaner", "Bathroom Cleaner",
        "Glass Cleaner", "Kitchen Cleaner", "All-Purpose Cleaner", "Stain Remover", "Dishwash Bar", "Dishwash Liquid",
        "Scrub Pad", "Steel Scrubber", "Toilet Brush", "Floor Cleaner", "Room Spray", "Disinfectant Spray",
        "Surface Cleaner", "Laundry Basket", "Bucket", "Mop Stick", "Dustpan", "Hand Gloves", "Laundry Bag",
        "Cloth Clips", "Drying Stand", "Cleaning Brush", "Window Wiper", "Garbage Bag", "Dustbin", "Insect Spray",
        "Cockroach Gel", "Drain Cleaner", "Napthalene Balls", "Toilet Freshener", "Scented Sachets", "Wiper",
        "Cleaning Duster"
    ],
    "Kitchen Essentials": [
        "Non-stick Pan", "Pressure Cooker", "Tawa", "Kadai", "Mixing Bowl", "Knife Set", "Cutting Board",
        "Peeler", "Grater", "Strainer", "Tongs", "Rolling Pin", "Chapati Board", "Measuring Cups", "Spice Box",
        "Ladle Set", "Serving Spoon", "Serving Bowl", "Storage Containers", "Lunch Box", "Water Bottle",
        "Thermos Flask", "Oil Dispenser", "Salt Shaker", "Whisk", "Mortar & Pestle", "Lemon Squeezer", "Colander",
        "Chopping Tray", "Tiffin Box", "Masala Dabba", "Rice Cooker", "Hand Blender", "Mixer Grinder", "Juicer",
        "Toaster", "Microwave Bowl", "Oven Gloves", "Apron"
    ],
    "Ready to Cook": [
        "Instant Biryani", "Ready Dosa Batter", "Ready Idli Batter", "Ready Chapati", "Instant Pasta", "Ready Pizza Base",
        "Frozen Samosa", "Frozen Kebab", "Frozen Chicken Popcorn", "Ready Pulao", "Ready Fried Rice", "Ready Dal Tadka",
        "Ready Rajma", "Ready Chole", "Frozen Spring Roll", "Frozen Paratha", "Instant Poha", "Instant Upma",
        "Frozen Naan", "Ready Soup", "Ready Curry", "Microwave Pasta", "Ready Noodles", "Ready Bhindi Fry",
        "Frozen Pav Bhaji", "Instant Pongal", "Frozen Veg Cutlet", "Instant Khichdi", "Instant Uttapam",
        "Microwave Dhokla", "Frozen Idli", "Frozen Tikki", "Frozen Malai Kofta", "Frozen Paneer Butter Masala",
        "Ready Mix Halwa", "Instant Kheer", "Ready Mix Gulab Jamun", "Frozen Lasagna", "Ready Mix Rasmalai"
    ],
    "Sweets & Desserts": [
        "Rasgulla", "Gulab Jamun", "Kaju Katli", "Soan Papdi", "Barfi", "Milk Cake", "Peda", "Halwa", "Ladoo",
        "Jalebi", "Imarti", "Cham Cham", "Rabri", "Basundi", "Mysore Pak", "Rasmalai", "Kalakand", "Balushahi",
        "Chikki", "Ghee Mysore Pak", "Ice Cream", "Kulfi", "Chocolate Bar", "Brownie", "Pastry", "Cake", "Donut",
        "Waffle", "Pudding", "Fruit Custard", "Cheesecake", "Tiramisu", "Chocolate Mousse", "Dry Fruit Halwa",
        "Kesari", "Kheer", "Modak", "Puran Poli", "Til Laddu"
    ],
    "Beverage Mixes": [
        "Instant Coffee", "Instant Tea", "Hot Chocolate Mix", "Milk Shake Mix", "Badam Milk Mix", "Malt Drink Mix",
        "Protein Shake Mix", "Thandai Mix", "Falooda Mix", "Jaljeera Mix", "Jeera Soda Mix", "Fruit Squash",
        "Lemonade Mix", "Energy Drink Powder", "Lassi Mix", "Cold Coffee Mix", "Instant Chai Premix", "Herbal Tea Mix",
        "Detox Drink Mix", "Masala Milk Mix", "Iced Tea Mix", "Cocktail Syrup", "Mocktail Syrup", "Soda Concentrate",
        "Fruit Punch Concentrate", "Instant Soup Mix", "Buttermilk Mix", "Digestive Drink Mix", "Nimbu Pani Mix",
        "Rose Syrup", "Khus Syrup", "Mango Crush", "Strawberry Crush", "Orange Squash", "Pineapple Squash",
        "Apple Juice Concentrate", "Mint Drink Mix", "Bar Syrup", "Coffee Premix"
    ],
    "Seasonal Specials": [
        "Holi Colors", "Diwali Diyas", "Christmas Tree", "Eid Sevaiya", "Navratri Garba Dress", "Rakhi", "Valentine Chocolates",
        "Ganesh Idol", "Janmashtami Flute", "Pongal Rice", "Makar Sankranti Til", "New Year Cake", "Raksha Bandhan Sweets",
        "Lohri Popcorn", "Durga Idol", "Christmas Plum Cake", "Ganpati Decoration", "Holi Gujiya", "Kite", "Til Laddu",
        "Ramzan Dates", "Diwali Sweets", "Diwali Crackers", "Onam Chips", "Christmas Wreath", "Dussehra Bow & Arrow",
        "Vrat Snacks", "Falahari Namkeen", "Holi Pichkari", "Karwa Chauth Thali", "Diya Stand", "Festival Lights",
        "Christmas Stockings", "Raksha Bandhan Card", "Valentine Roses", "Festival Garland", "Vrat Sabudana",
        "Puja Samagri", "Festival Sweets"
    ],
    "Cold Beverages": [
        "Soft Drinks", "Soda", "Cold Coffee", "Ice Tea", "Energy Drinks", "Fruit Juices", "Milkshake", "Buttermilk",
        "Lassi", "Coconut Water", "Sugarcane Juice", "Aam Panna", "Jaljeera", "Chaas", "Badam Drink", "Mocktail",
        "Smoothie", "Iced Americano", "Lemon Iced Tea", "Cold Brew", "Flavored Milk", "Fruit Punch", "Mint Cooler",
        "Berry Smoothie", "Watermelon Juice", "Mango Shake", "Rose Milk", "Thandai", "Mint Mojito", "Blue Lagoon",
        "Chocolate Shake", "Vanilla Shake", "Oreo Shake", "Strawberry Shake", "Jeera Soda", "Sattu Drink",
        "Detox Water", "Lemon Soda", "Litchi Juice", "Musk Melon Juice"
    ]
}
